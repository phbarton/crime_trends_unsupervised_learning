# %% [markdown]
# # Predictive Crime Analytics: From Clusters to District-Level Action Plans

# %% [markdown]
# # Purpose
# This notebook aims to analyze crime data to identify patterns and trends, cluster similar crime incidents, and develop actionable insights for district-level crime prevention strategies using recommender systems.

# %% [markdown]
# # Background
# Crime analytics involves the use of data analysis techniques to understand crime patterns and trends. By clustering similar crime incidents, we can identify hotspots and common factors contributing to criminal activities. This information can be used to develop targeted action plans for different districts, enhancing public safety and resource allocation. This project uses real crime data reported in Raleigh, NC, to demonstrate the application of clustering algorithms and recommender systems in crime analytics.

# %% [markdown]
# # Methodology
# 1. Data Collection: Gather crime data from reliable sources, including incident reports, locations, times, and types of crimes.
# 2. Data Preprocessing: Clean and preprocess the data to handle missing values, outliers, and inconsistencies.
# 3. Exploratory Data Analysis (EDA): Analyze the data to identify trends, patterns, and correlations.
# 4. Clustering: Apply clustering algorithms (e.g., K-Means, DBSCAN) to group similar crime incidents based on features such as location, time, and type of crime.
# 5. Non-negative Matrix Factorization (NMF): Use NMF to reduce dimensionality and extract latent features from the clustered data.
# 6. Recommender System: Develop a recommender system to suggest district-level action plans based on the identified clusters.
# 7. Prediction and Evaluation: Test the recommender system's effectiveness in predicting crime trends and evaluate its performance using appropriate metrics.

# %% [markdown]
# # Ethical Considerations

# %% [markdown]
# ## Bias and Fairness
# This dataset contains information related to crime incidents in the Raleigh, NC area. While there is no identifying information about individuals in the dataset, there do exist incident report numbers and location data that could potentially be used to identify individuals involved in the incidents, or may contain embedded biases based on demographic information. It is crucial to ensure that the analysis does not perpetuate existing biases or lead to unfair treatment of certain communities.

# %% [markdown]
# ## Privacy
# When working with crime data, it is essential to respect the privacy of individuals involved in the incidents. Analysis will be conducted in a manner that protects personal information and adheres to data protection regulations

# %% [markdown]
# ## Responsible Use
# The insights derived from this analysis should be used responsibly to enhance public safety without infringing on individual rights. Recommendations should focus on community engagement and preventive measures rather than punitive actions.

# %% [markdown]
# # Dataset Description
# The dataset used in this analysis is the "Raleigh Police Incidents (NIBRS)" dataset, which contains detailed records of crime incidents reported to the Raleigh Police Department. The dataset includes various attributes such as incident type, location, date, time, and other relevant details. The data is sourced from Open Data Raleigh and is publicly available for analysis (City of Raleigh, 2014–present). The data dictionary for this dataset is as follows:
#
# | Column Name            |                                               Description                                               | Data Type  | Feature Type       |
# |:-----------------------|:-------------------------------------------------------------------------------------------------------:|:-----------|:-------------------|
# | Case Number            |  A unique identifier assigned to each police case. Used for tracking and referencing specific reports.  | String     | Unique Identifier  |
# | Crime_Category         |                                         Type of crime committed                                         | String     | Categorical        |
# | Crime Code             |          A standardized code representing the type of crime based on internal classification.           | String     | Categorical        |
# | Crime Description      |                               A brief description of the crime incident.                                | String     | Categorical        |
# | Crime Type             |                      A broader classification of the crime (e.g., Theft, Assault).                      | String     | Categorical        |
# | Reported Block Address |                       The anonymized block address where the crime was reported.                        | String     | Categorical        |
# | City of Incident       |                               The city where the crime incident occurred.                               | String     | Categorical        |
# | District               |                            The police district where the crime was reported.                            | String     | Categorical        |
# | Reported Date          |                                  The date when the crime was reported.                                  | Date       | Temporal           |
# | Reported Year          |                                  The year when the crime was reported.                                  | Integer    | Categorical        |
# | Reported Month         |                                 The month when the crime was reported.                                  | Integer    | Categorical        |
# | Reported Day           |                            The day of the month when the crime was reported.                            | Integer    | Categorical        |
# | Reported Hour          |                            The hour of the day when the crime was reported.                             | Integer    | Categorical        |
# | Reported Day of Week   |                            The day of the week when the crime was reported.                             | String     | Categorical        |
# | Latitude               |                         The latitude coordinate of the crime incident location.                         | Float      | Numerical          |
# | Longitude              |                        The longitude coordinate of the crime incident location.                         | Float      | Numerical          |
# | Agency                 |                      The law enforcement agency that reported the crime incident.                       | String     | Categorical        |
# | Updated_Date           |                        The date when the crime incident record was last updated.                        | Date       | Temporal           |
#
# It should be noted that this dataset is updated daily from the hosting website. The data used in this analysis was downloaded on November 14, 2025. It is too large to be included directly in this repository but can be accessed via the provided download link.

# %% [markdown]
# # Global Actions

# %% [markdown]
# ## Importing Libraries

# %%
import os
import warnings

import gdown
import pandas as pd
import seaborn as sns

sns.set_theme(style='ticks', palette='pastel')
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Notebook-Level Constants

# %%
random_seed = 42
file_id = '1xNzeXy8IXL21qgmVym5OV14PZ3kmNhox'
output_file = 'crime_data.csv'

# %% [markdown]
# ## Download the Dataset

# %%
# Download the file using gdown (handles large files with virus scan warnings)
gdown.download(f'https://drive.google.com/uc?id={file_id}', output_file, quiet=True)

# Define data types for columns
dtype_spec = {
    'Case Number': 'string',
    'Crime_Category': 'string',
    'Crime Code': 'string',
    'Crime Description': 'string',
    'Crime Type': 'string',
    'Reported Block Address': 'string',
    'City of Incident': 'string',
    'District': 'string',
    'Reported Year': 'Int64',
    'Reported Month': 'Int64',
    'Reported Day': 'Int64',
    'Reported Hour': 'Int64',
    'Reported Day of Week': 'string',
    'Latitude': 'float64',
    'Longitude': 'float64',
    'Agency': 'string',
    'x': 'float64',
    'y': 'float64'
}

# Read the downloaded CSV file with specified dtypes
# Note: Date columns will be parsed separately
df = pd.read_csv(
    output_file,
    dtype=dtype_spec,
    parse_dates=['Reported Date', 'Updated_Date']
)

# Clean up the downloaded file - it's no longer needed, and we don't want to store large files in the repo
os.remove(output_file)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Basic Information

# %% [markdown]
# View the basic information about the dataset. This is a large dataset with 595,963 observations and 23 features. There are several features with missing values, which will need to be addressed during data cleaning. Since we want to create a rich dataset for clustering and recommendation, we will attempt to impute missing values where possible. Dropping observations with missing values may lead to loss of valuable information and will be considered as a last resort.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595963 entries, 0 to 595962
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   OBJECTID                595963 non-null  int64
#  1   GlobalID                595963 non-null  object
#  2   Case Number             445478 non-null  string
#  3   Crime_Category          595963 non-null  string
#  4   Crime Code              595963 non-null  string
#  5   Crime Description       595963 non-null  string
#  6   Crime Type              386964 non-null  string
#  7   Reported Block Address  445357 non-null  string
#  8   City of Incident        445352 non-null  string
#  9   City                    595957 non-null  object
#  10  District                595963 non-null  string
#  11  Reported Date           595963 non-null  datetime64[ns]
#  12  Reported Year           595963 non-null  Int64
#  13  Reported Month          595963 non-null  Int64
#  14  Reported Day            595963 non-null  Int64
#  15  Reported Hour           595963 non-null  Int64
#  16  Reported Day of Week    595963 non-null  string
#  17  Latitude                595963 non-null  float64
#  18  Longitude               595963 non-null  float64
#  19  Agency                  595963 non-null  string
#  20  Updated_Date            595963 non-null  datetime64[ns]
#  21  x                       443301 non-null  float64
#  22  y                       443301 non-null  float64
# dtypes: Int64(4), datetime64[ns](2), float64(4), int64(1), object(2), string(10)
# memory usage: 106.9+ MB

# %% [markdown]
# View the first few rows of the dataset

# %%
df.head()
# Out:
#    OBJECTID                              GlobalID Case Number Crime_Category  \
# 0     12001  9cdee08d-11c8-4789-864b-6965a1b2e620        <NA>  MISCELLANEOUS
# 1     12002  6f6731f4-dd64-44c7-895c-555de2703c8a        <NA>  MISCELLANEOUS
# 2     12003  f0fd0e92-448e-4ca8-86c9-e6594564318b        <NA>  MISCELLANEOUS
# 3     12004  8a212e84-7b53-478a-b225-c212aa25d7fd        <NA>  MISCELLANEOUS
# 4     12005  01614b98-48f5-4374-a561-17c4b29d8857        <NA>  MISCELLANEOUS
#
#   Crime Code                         Crime Description Crime Type  \
# 0        81H  Miscellaneous/Missing Person (18 & over)       <NA>
# 1        81A      Miscellaneous/All Other Non-Offenses       <NA>
# 2        81F           Miscellaneous/Mental Commitment       <NA>
# 3        81A      Miscellaneous/All Other Non-Offenses       <NA>
# 4        81A      Miscellaneous/All Other Non-Offenses       <NA>
#
#   Reported Block Address City of Incident     City  ... Reported Month  \
# 0                   <NA>             <NA>  RALEIGH  ...              1
# 1                   <NA>             <NA>  RALEIGH  ...              7
# 2                   <NA>             <NA>  RALEIGH  ...              3
# 3                   <NA>             <NA>  RALEIGH  ...              3
# 4                   <NA>             <NA>  RALEIGH  ...             12
#
#   Reported Day  Reported Hour  Reported Day of Week  Latitude  Longitude  \
# 0           14             22              Saturday       0.0        0.0
# 1           29              8              Saturday       0.0        0.0
# 2            6             22                Sunday       0.0        0.0
# 3           24              0               Tuesday       0.0        0.0
# 4           22             19               Tuesday       0.0        0.0
#
#   Agency        Updated_Date   x   y
# 0    RPD 2017-01-19 20:11:28 NaN NaN
# 1    RPD 2017-08-01 14:06:50 NaN NaN
# 2    RPD 2016-04-14 14:43:38 NaN NaN
# 3    RPD 2015-03-25 19:24:28 NaN NaN
# 4    RPD 2016-01-13 19:29:51 NaN NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Data Cleaning
# There are some obvious features which can be dropped for the purpose of clustering and recommendation. The following features will be dropped:
# - `OBJECTID`
# - `GlobalID`
# - `Case Number`
# - `Updated_Date`
# - `x`
# - `y`
#
# These columns are either unique identifiers, useless information or redundant for the analysis.

# %%
df = df.drop(columns=[
    'OBJECTID', 'GlobalID', 'Case Number', 'Updated_Date', 'x', 'y'
]) if all(col in df.columns for col in [
    'OBJECTID', 'GlobalID', 'Case Number', 'Updated_Date', 'x', 'y'
]) else df

# %% [markdown]
# We can also remove the `Agency` column since all the records are from the same agency, Raleigh Police Department.

# %%
df['Agency'].value_counts()
# Out:
# Agency
# RPD    595963
# Name: count, dtype: Int64

# %%
df = df.drop(columns=['Agency']) if 'Agency' in df.columns else df

# %% [markdown]
# The `Reported Date` column is redundant since we have the year, month, day, hour, and day of the week in separate columns. We can drop this column as well.

# %%
df = df.drop(columns=['Reported Date']) if 'Reported Date' in df.columns else df

# %% [markdown]
# ## Impute Missing Values

# %% [markdown]
# There are numerous missing values in the remaining columns. We will impute missing values so that we can avoid dropping rows and losing valuable information. First, we need to find which columns have missing values after the initial cleaning.

# %%
[col for col in df.columns if df[col].isna().sum() > 0]
# Out:
# ['Crime Type', 'Reported Block Address', 'City of Incident', 'City']

# %% [markdown]
# Additionally, there are several observations where the `latitude` and `longitude` values are both zero, which is not a valid location. We will treat these as missing values as well. We will do an imputation strategy based on the mean values of the `Reported Block Address` for the missing `latitude` and `longitude` values. If the `Reported Block Address` is also missing, we will use the mean values for the respective `District`. Finally, if the `District` is also missing, we will use the overall mean values for the `City of Incident`. Should the values still be missing after these backoffs, we will drop the rows as a last resort.

# %% [markdown]
# ### Crime Type

# %% [markdown]
# To impute the crime type, we will use the most common value for the respective `Crime Code`. Since there are no missing values in the `Crime Code` column, this will ensure that we have a reasonable imputation for the missing `Crime Type` values.

# %%
# Precompute the mode of Crime Type for each Crime Code
crime_type_mode = df.groupby('Crime Code')['Crime Type'].value_counts()
crime_type_mode = crime_type_mode.groupby(level=0).idxmax().apply(lambda x: x[1])
default_crime_type = df['Crime Type'].mode()[0]


# Create a function which we can apply to impute missing Crime Type values
def impute_crime_type(row):
    if pd.isna(row['Crime Type']):
        return crime_type_mode.get(row['Crime Code'], default_crime_type)
    return row['Crime Type']


# Now, apply the function to the DataFrame
df['Crime Type'] = df.apply(impute_crime_type, axis=1)

# Show that there are no more missing values in Crime Type
df['Crime Type'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### City of Incident

# %% [markdown]
# The `City of Incident` will be our "city of record" for the data analysis. We will use the value of `City` for imputation. However, `City` has more values than `City of Incident` and some of them may not be valid or represent the same location. Therefore, we will try to clean the `City` values first by removing any commas, extra spaces, and converting to upper case. Then, we will try to match the cleaned `City` values to the existing `City of Incident` values. If a match is found, we will use that value for imputation. If no match is found, we will use the most common `City of Incident` value for imputation.

# %%
# Precompute the most common City of Incident value
city_of_incident_mode = df['City of Incident'].mode()[0]

# Clean the City values
# First, strip everthing to the right of the first comma and the comma itself
df['City'] = df['City'].str.split(',').str[0]

# Then remove any remaining commas, extra spaces, and convert to upper case
df['City'] = df['City'].str.replace(',', '').str.strip().str.upper()

# Create the mapping from cleaned City to City of Incident
city_mapping = {}
unique_cities_of_incident = df['City of Incident'].unique()

for city in df['City'].unique():
    if not isinstance(city, str):
        city_mapping[city] = city_of_incident_mode
        continue

    cleaned_city = city.strip().upper()
    if cleaned_city in unique_cities_of_incident:
        city_mapping[city] = cleaned_city
    else:
        city_mapping[city] = city_of_incident_mode


# Create a function which we can apply to impute missing City of Incident values
def impute_city_of_incident(row):
    if pd.isna(row['City of Incident']):
        return city_mapping.get(row['City'], city_of_incident_mode)
    return row['City of Incident']


# Now, apply the function to the DataFrame
df['City of Incident'] = df.apply(impute_city_of_incident, axis=1)

# Drop the City column as it is no longer needed
df = df.drop(columns=['City']) if 'City' in df.columns else df

# Show that there are no more missing values in City of Incident
df['City of Incident'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Latitude and Longitude

# %% [markdown]
# Our final imputation will be for the `Latitude` and `Longitude` columns. We will use the strategy outlined earlier to impute missing values based on the `Reported Block Address`, `District`, and `City of Incident`. It should be noted that "missing" values include both `NaN` values and zero values for both `Latitude` and `Longitude`.

# %%
# Precompute mean Latitude and Longitude for each Reported Block Address where the lat/lon are not zero
block_means = df[(df['Latitude'] != 0) & (df['Longitude'] != 0)].groupby('Reported Block Address')[
    ['Latitude', 'Longitude']].mean()

# Precompute mean Latitude and Longitude for each District where the lat/lon are not zero
district_means = df[(df['Latitude'] != 0) & (df['Longitude'] != 0)].groupby('District')[
    ['Latitude', 'Longitude']].mean()

# Precompute mean Latitude and Longitude for each City of Incident where the lat/lon are not zero
city_means = df[(df['Latitude'] != 0) & (df['Longitude'] != 0)].groupby('City of Incident')[
    ['Latitude', 'Longitude']].mean()


# Create a function which we can apply to impute missing Latitude and Longitude values
def impute_lat_lon(row):
    if pd.isna(row['Latitude']) or row['Latitude'] == 0 or pd.isna(row['Longitude']) or row['Longitude'] == 0:
        # Try to impute based on Reported Block Address
        if row['Reported Block Address'] in block_means.index:
            return block_means.loc[row['Reported Block Address'], 'Latitude'], block_means.loc[
                row['Reported Block Address'], 'Longitude']
        # Try to impute based on District
        elif row['District'] in district_means.index:
            return district_means.loc[row['District'], 'Latitude'], district_means.loc[row['District'], 'Longitude']
        # Try to impute based on City of Incident
        elif row['City of Incident'] in city_means.index:
            return city_means.loc[row['City of Incident'], 'Latitude'], city_means.loc[
                row['City of Incident'], 'Longitude']
    return row['Latitude'], row['Longitude']


# Now, apply the function to the DataFrame
df[['Latitude', 'Longitude']] = df.apply(
    lambda row: pd.Series(impute_lat_lon(row)), axis=1
)

# Drop any remaining rows with missing Latitude or Longitude values or have zero values
df = df.dropna(subset=['Latitude', 'Longitude'])
df = df[(df['Latitude'] != 0) & (df['Longitude'] != 0)]

# Show that there are no more missing values in Latitude and Longitude
df['Latitude'].isna().sum(), df['Longitude'].isna().sum()
# Out:
# (np.int64(0), np.int64(0))

# %% [markdown]
# After the data cleaning and imputation, the dataset now has the following shape:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595963 entries, 0 to 595962
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Crime_Category          595963 non-null  string
#  1   Crime Code              595963 non-null  string
#  2   Crime Description       595963 non-null  string
#  3   Crime Type              595963 non-null  object
#  4   Reported Block Address  445357 non-null  string
#  5   City of Incident        595963 non-null  object
#  6   District                595963 non-null  string
#  7   Reported Year           595963 non-null  Int64
#  8   Reported Month          595963 non-null  Int64
#  9   Reported Day            595963 non-null  Int64
#  10  Reported Hour           595963 non-null  Int64
#  11  Reported Day of Week    595963 non-null  string
#  12  Latitude                595963 non-null  float64
#  13  Longitude               595963 non-null  float64
# dtypes: Int64(4), float64(2), object(2), string(6)
# memory usage: 65.9+ MB

# %%
df.head()
# Out:
#   Crime_Category Crime Code                         Crime Description  \
# 0  MISCELLANEOUS        81H  Miscellaneous/Missing Person (18 & over)
# 1  MISCELLANEOUS        81A      Miscellaneous/All Other Non-Offenses
# 2  MISCELLANEOUS        81F           Miscellaneous/Mental Commitment
# 3  MISCELLANEOUS        81A      Miscellaneous/All Other Non-Offenses
# 4  MISCELLANEOUS        81A      Miscellaneous/All Other Non-Offenses
#
#                 Crime Type Reported Block Address City of Incident   District  \
# 0  CRIMES AGAINST PROPERTY                   <NA>          RALEIGH  Northeast
# 1  CRIMES AGAINST PROPERTY                   <NA>          RALEIGH      North
# 2  CRIMES AGAINST PROPERTY                   <NA>          RALEIGH  Southwest
# 3  CRIMES AGAINST PROPERTY                   <NA>          RALEIGH  Southeast
# 4  CRIMES AGAINST PROPERTY                   <NA>          RALEIGH  Southeast
#
#    Reported Year  Reported Month  Reported Day  Reported Hour  \
# 0           2017               1            14             22
# 1           2017               7            29              8
# 2           2016               3             6             22
# 3           2015               3            24              0
# 4           2015              12            22             19
#
#   Reported Day of Week   Latitude  Longitude
# 0             Saturday  35.849718 -78.571685
# 1             Saturday  35.852810 -78.615866
# 2               Sunday  35.776751 -78.688976
# 3              Tuesday  35.769859 -78.595591
# 4              Tuesday  35.769859 -78.595591

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# # Works Cited
# - City of Raleigh. (2014–present). Raleigh Police Incidents (NIBRS) [Data set]. Open Data Raleigh. https://data-ral.opendata.arcgis.com/datasets/ral::raleigh-police-incidents-nibrs/about
